# %% [markdown]
# # **Import and load the data file**

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# # **Preprocess data**

# %%
import nltk
nltk.download('punkt')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import nltk
nltk.download('wordnet')
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# # **Create training and testing data**

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# # **Build the model**

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 2ms/step - loss: 2.2062 - accuracy: 0.1615
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1959 - accuracy: 0.1236
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1065 - accuracy: 0.2335
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9619 - accuracy: 0.2830
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8361 - accuracy: 0.5350
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7014 - accuracy: 0.5598
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6595 - accuracy: 0.4707
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5456 - accuracy: 0.5132
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4851 - accuracy: 0.6834
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3126 - accuracy: 0.6651
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1852 - accuracy: 0.7290
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1167 - accuracy: 0.6678
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0778 - accuracy: 0.6645
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9269 - accuracy: 0.7884
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7772 - accuracy: 0.8579
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9298 - accuracy: 0.8014
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8418 - accuracy: 0.8015
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6129 - accuracy: 0.8849
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.7814
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5168 - accuracy: 0.8450
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5620 - accuracy: 0.8924
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6376 - accuracy: 0.8232
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.8406
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.8365
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.9716
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.9076
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.9046
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2930 - accuracy: 0.9120
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.9578
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2692 - accuracy: 0.9854
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.9579
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.9755
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.8623
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9941
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.9455
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1881 - accuracy: 0.9273
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8494
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9834
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9455
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.9602
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.9902
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.8961
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9408
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1333 - accuracy: 0.9718
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1601 - accuracy: 0.9699
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9826
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9720
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9720
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9167
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1092 - accuracy: 0.9826
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.9455
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9961
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9383
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9826
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9720
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9862
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9918
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9780
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.8994
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9941
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9685
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9892
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9612
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9941
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 0.9629
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9629
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9720
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.8994
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9699
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9918
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9826
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9826
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 0.9720
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9720
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4305 - accuracy: 0.9309
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9918
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9826
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9535
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9629
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9918
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9629
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9720
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9780
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9941
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9826
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9961
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9862
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9941
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9811
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.9447
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9892
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9720
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9629
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9892
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9629
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9629
# model created

# %% [markdown]
# # **Predict the response**

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('/content/chatbot_model.h5')
import json
import random
intents = json.loads(open('/intents.json').read())
words = pickle.load(open('/content/words.pkl','rb'))
classes = pickle.load(open('/content/classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'    # tell X clients to use our virtual DISPLAY :1.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.8 [784 kB]
# Fetched 784 kB in 1s (833 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 160980 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.8_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.8) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.8) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# # **Graphical User Interface**

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *



def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
